# %% [markdown]
# <a href="https://colab.research.google.com/github/indrajit1984/Deep-learning/blob/code_basics/GPU_Benchmarking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np
# Version Information
# tensorflow 2.2.0 , Cudnn7.6.5 and Cuda 10.1 , python 3.8

# %%
tf.config.experimental.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
tf.__version__
# Out:
# '2.19.0'

# %%
tf.test.is_built_with_cuda()
# Out:
# True

# %%
(X_train, y_train), (X_test,y_test) = tf.keras.datasets.cifar10.load_data()
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
X_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
y_train.shape
# Out:
# (50000, 1)

# %%
def plot_sample(index):
    plt.figure(figsize = (10,1))
    plt.imshow(X_train[index])

# %%
plot_sample(0)

# %%
classes = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

# %%
plot_sample(3)
classes[y_train[3][0]]
y_train[:3]
# Out:
# array([[6],
#        [9],
#        [9]], dtype=uint8)

# %%
y_test.shape
# Out:
# (10000, 1)

# %%
X_train_scaled = X_train / 255
X_test_scaled = X_test / 255

# %%
y_train_categorical = keras.utils.to_categorical(
    y_train, num_classes=10, dtype='float32'
)
y_test_categorical = keras.utils.to_categorical(
    y_test, num_classes=10, dtype='float32'
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-985427316.py in <cell line: 0>()
# ----> 1 y_train_categorical = keras.utils.to_categorical(
#       2     y_train, num_classes=10, dtype='float32'
#       3 )
#       4 y_test_categorical = keras.utils.to_categorical(
#       5     y_test, num_classes=10, dtype='float32'
#
# TypeError: to_categorical() got an unexpected keyword argument 'dtype'
